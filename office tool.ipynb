# %%
import sqlite3

conn=sqlite3.connect("office.db")
cursor=conn.cursor()
cursor.execute("CREATE TABLE  IF NOT EXISTS employees (id INTEGER PRIMARY KEY, name TEXT, department TEXT)")

def create():
    name = input("Enter the employee name: ")
    department = input("Enter the department name: ")
    cursor.execute("INSERT INTO employees (name, department) VALUES (?, ?)", (name, department))
    conn.commit()

def read():
    cursor.execute("SELECT * FROM employees")
    rows = cursor.fetchall()
    for row in rows:
        print(row)

def update():
    id = int(input("Enter ID: "))
    name = input("Enter new name: ")
    department = input("Enter new department: ")
    cursor.execute("UPDATEemployees SET name=?, department=? WHERE id=?", (name, department, id))
    conn.commit()

def delete():
    id = int(input("Enter ID: "))
    cursor.execute("DELETE FROM employees WHERE id=?", (id,))
    conn.commit()

while True:
    print("1. Employee name")
    print("2. Read Employees")
    print("3. Update Employee")
    print("4. Delete Employee")
    print("5. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        create()
    elif choice == '2':
        read()
    elif choice == '3':
        update()
    elif choice == '4':
        delete()
    elif choice == '5':
        break
    else:
        print("Invalid choice. Please try again.")

conn = sqlite3.connect("office.db")
cursor = conn.cursor()
cursor.execute("CREATE TABLE IF NOT EXISTS employees (id INTEGER PRIMARY KEY, name TEXT, department TEXT)")

def create():
    name = input("Enter the employee name: ")
    department = input("Enter the department name: ")
    cursor.execute("INSERT INTO employees (name, department) VALUES (?, ?)", (name, department))
    conn.commit()

def read():
    cursor.execute("SELECT * FROM employees")
    rows = cursor.fetchall()
    for row in rows:
        print(row)

def update():
    id = int(input("Enter ID: "))
    name = input("Enter new name: ")
    department = input("Enter new department: ")
    cursor.execute("UPDATE employees SET name=?, department=? WHERE id=?", (name, department, id))
    conn.commit()

def delete():
    id = int(input("Enter ID: "))
    cursor.execute("DELETE FROM employees WHERE id=?", (id,))
    conn.commit()

while True:
    print("1. Create Employee")
    print("2. Read Employees")
    print("3. Update Employee")
    print("4. Delete Employee")
    print("5. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        create()
    elif choice == '2':
        read()
    elif choice == '3':
        update()
    elif choice == '4':
        delete()
    elif choice == '5':
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Create Employee
# 2. Read Employees
# 3. Update Employee
# 4. Delete Employee
# 5. Exit
